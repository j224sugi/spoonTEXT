# %%
import subprocess
import os
import pandas as pd

def editClass(Spoonfile,CKfile,outPutFolder,fileName):
    df=pd.read_csv(CKfile)
    CK=df[["file","class","wmc","tcc","loc"]]
    CK["class"]=CK["class"].str.replace("$Anonymous","$")
    spoon=pd.read_csv(Spoonfile)
    join=spoon.merge(CK,how="inner",on=["file","class"])
    
    join.to_csv(outPutFolder+"class"+str(fileName)+".csv")#後でフォルダ名を入力する

def editMethod(SpoonFile,CKFile,outPutFolder,fileName):
    df=pd.read_csv(CKFile)
    CK=df[["file","class","method","wmc","loc"]]
    spoon=pd.read_csv(SpoonFile)
    join=spoon.merge(CK,how="inner",on=["file","class","method"])
    join.to_csv(outPutFolder+"method"+str(fileName)+".csv")#後でフォルダ名を入力する


projectFolder="C:/Users/syuuj/jsoup"
outPutFolder="C:/Users/syuuj/SpoonCK_data/"
absolutePath=os.getcwd()

getCommitID="git rev-list HEAD"
SpoonAnalyze=["java","-jar","spoon/demo/target/demo-1.0-snapshot.jar",projectFolder,"spoonCK_data/"]
CKAnalyze=["java","-jar","ck/target/ck-0.7.1-SNAPSHOT-jar-with-dependencies.jar",projectFolder,"true","0","true","spoonCK_data/"]

subprocess.run(["git","checkout","master"],cwd=projectFolder,check=True)
cp=subprocess.run(getCommitID.split(),encoding="utf-8",capture_output=True,text=True,cwd=projectFolder,check=True)
allCommitID=cp.stdout.split()
dataFolder="spoonCK_data/class.csv"
CKData=["class","method","field","variable"]
for i in range(len(allCommitID)):
    commitID=allCommitID[i]
    subprocess.run(["git","checkout","-f",commitID],cwd=projectFolder,encoding="utf-8",check=True)
    subprocess.run(SpoonAnalyze,check=True,cwd=absolutePath)
    print(i)
    #subprocess.run(CKAnalyze,check=True,cwd=absolutePath)
    #editClass("spoonCK_data/spoonClass.csv","spoonCK_data/class.csv",outPutFolder,i+693)
    #editMethod("spoonCK_data/spoonMethod.csv","spoonCK_data/method.csv",outPutFolder,i+693)

# %%
import os

absolutePath = os.getcwd()
print(absolutePath)
# Out:
# c:\Users\sugii syuji\spoonTEXT\demo

# %% [markdown]
# 1.gitプロジェクトのrootとoutputFolderを与える
#
# 2.gitプロジェクトを最新の状態にする
#
# 3.gitのコミットIDを取得する
#
# 4.順番にコミットIDにcheckoutしていきデータを取得する
#
# 4.Spoonを実行する　→　spoonプロジェクトを入れておく必要がある。spoonCK_dataに一時保存される
#
# 5.CKを実行する　→　CKプロジェクトを入れておく必要がある。spoonCK_dataに一時保存される。おそらく、ckのファイル名は重複が許されていない
#
# 6.4と5を合わせる。
#
# spoonの場合はファイル指定して複数のファイルを一度に実行することができるが、ckの場合プロジェクト毎かファイル単位でしか実行することができない。
# そのため、CKにおいて、ファイルを結合する必要がある。
